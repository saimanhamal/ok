# %% [markdown]
# <a href="https://colab.research.google.com/github/saimanhamal/ok/blob/main/Workshop8part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.listdir('/content/drive/MyDrive')
# Out:
# ['Colab Notebooks',
#  'Untitled presentation (8).gslides',
#  'Week6Functions_9310270a-aed1-4e9b-86c5-9e970e035865_95176_.gslides',
#  'Tutorial6Function_2bdb8c71-40cc-459a-84d7-708e66376d20_95176_.gslides',
#  'Untitled presentation (7).gslides',
#  'Tutorial7FileHandling_a56d9016-fdb1-492f-a911-3a0dc261a32a_95176_ (1).gslides',
#  'Tutorial7FileHandling_a56d9016-fdb1-492f-a911-3a0dc261a32a_95176_.gslides',
#  'Week7FileHandling_ac323488-846f-4655-96f8-2c6846c0d4e2_95176_.gslides',
#  '4CS015Lec3_HCK11_f2b2bc67-230f-4664-9866-53bd85511b10_95473_.gslides',
#  'Untitled presentation (6).gslides',
#  'Tutorial9ExceptionHandling1_73f0791a-5ba3-47e4-a76c-4d2e4c9b3462_95176_ (1).gslides',
#  'Tutorial9ExceptionHandling1_73f0791a-5ba3-47e4-a76c-4d2e4c9b3462_95176_.gslides',
#  'Tutorial11Recursion_76288f6d-1e53-4427-82ed-9e43d3ba4aae_95176_ (1).gslides',
#  'Untitled presentation (5).gslides',
#  'Tutorial1_cae5ba49-1718-40ba-bafd-9c6ba0403d7b_161659_ (4).gslides',
#  'Tutorial1_cae5ba49-1718-40ba-bafd-9c6ba0403d7b_161659_ (3).gslides',
#  'Tutorial1_cae5ba49-1718-40ba-bafd-9c6ba0403d7b_161659_ (2).gslides',
#  'Tutorial1_cae5ba49-1718-40ba-bafd-9c6ba0403d7b_161659_ (1).gslides',
#  'Lecture1Introduction_5371d939-15cc-41f6-8ebb-98fcc1ae1977_95176_.gslides',
#  'Untitled presentation (4).gslides',
#  'Tutorialweek5_8836b9b9-d296-40e8-84ea-83faa3557b0c_161659_ (3).gslides',
#  'Tutorialweek5_8836b9b9-d296-40e8-84ea-83faa3557b0c_161659_ (2).gslides',
#  'Tutorialweek5_8836b9b9-d296-40e8-84ea-83faa3557b0c_161659_.gslides',
#  'Untitled presentation (3).gslides',
#  'TutorialWeek6_ac0e5475-1957-4caf-8a53-661612277f35_161659_.gslides',
#  '4CS020_CourseworkTemplate_f5bcedd0-3dd9-475c-b35b-b0e13b31d87c_89723_.gslides',
#  'Tutorial8_2d580b4f-c150-4c4f-9485-66dd0155141d_161659_.gslides',
#  'Untitled presentation (2).gslides',
#  'UnityPresentation.gslides',
#  'Tutorial1_cae5ba49-1718-40ba-bafd-9c6ba0403d7b_161659_.gslides',
#  'Tutorialweek5_8836b9b9-d296-40e8-84ea-83faa3557b0c_161659_ (1).gslides',
#  'TutorialWeek6_ac0e5475-1957-4caf-8a53-661612277f35_161659_ (1).gslides',
#  '4CS020_CourseworkTemplate.gslides',
#  'Contact Information.gform',
#  'Devplatform.gslides',
#  'Untitled presentation (1).gslides',
#  'Development Platform-\x0bRecruitment Portal.gslides',
#  'NMC lec 07 (1) image and pixel DEMO- Subash (1).gslides',
#  'Untitled presentation.gslides',
#  'Usability & Accessibility Testing Questionnaire.gform',
#  'Inside College.gdoc']

# %%
os.listdir('/content/drive/MyDrive/Colab Notebooks')
# Out:
# ['Workshop8part2.ipynb',
#  'Untitled0.ipynb',
#  'Saiman hamal_week3.ipynb',
#  'Untitled (1)',
#  'Untitled',
#  'Saiman_Hamal.ipynb',
#  'Saiman_Hamal_2408252_MidpointApproachMethod.ipynb',
#  'Saiman_Hamal__2408252_BisectionMethod.ipynb',
#  'Saiman_Hamal_2408252_NewtonMethod.ipynb',
#  'Saiman_Hamal_2408252_TrapezoidalApproaxMethod.ipynb',
#  'SaimanHamal(2408252)worksheet0',
#  'Copy of SaimanHamal(2408252)worksheet0',
#  'Untitled2.ipynb',
#  'Untitled1.ipynb',
#  'Untitled3.ipynb',
#  'Workshop1.ipynb',
#  'Ai',
#  'ws2.ipynb',
#  'Worksheet_1_Solutions.ipynb',
#  'Worksheet_0_Solutions.ipynb',
#  'Worksheet_1_Solutions (1).ipynb',
#  'Worksheet_1_Solutions .ipynb',
#  'Tutorial_1.ipynb',
#  'worksheet_2.ipynb',
#  'Worksheet_3.ipynb',
#  'Copy of devnagari digit.zip',
#  'tu4(keras).ipynb',
#  'tut4(tasks).ipynb',
#  'FruitinAmazon.zip',
#  'worksheet5.ipynb',
#  'worksheet6.ipynb',
#  'Untitled4.ipynb',
#  'Tutorial_7.ipynb',
#  'trumptweets_small.csv',
#  'trum_tweet_sentiment_analysis.csv',
#  'workshop8part1.ipynb']

# %% [markdown]
# ## Helper Function for Text Cleaning:
#
# Implement a Helper Function as per Text Preprocessing Notebook and Complete the following pipeline.

# %% [markdown]
# # Build a Text Cleaning Pipeline

# %%
import nltk
import re

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

stop_words = set(stopwords.words("english"))

def lower_order(text):
    return str(text).lower()

def remove_urls(text):
    return re.sub(r"http\S+|www\.\S+", " ", text)

def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"
                           u"\U0001F300-\U0001F5FF"
                           u"\U0001F680-\U0001F6FF"
                           u"\U0001F1E0-\U0001F1FF"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r" ", text)

def removeunwanted_characters(text):
    text = re.sub("@[A-Za-z0-9_]+"," ", text)
    text = re.sub("#[A-Za-z0-9_]+"," ", text)
    text = re.sub("[^0-9A-Za-z ]", " ", text)
    return re.sub("\s+", " ", text).strip()

def text_cleaning_pipeline(dataset, rule="lemmatize"):
    data = lower_order(dataset)
    data = remove_urls(data)
    data = remove_emoji(data)
    data = removeunwanted_characters(data)

    tokens = data.split()
    tokens = [word for word in tokens if word not in stop_words]

    wordnet = WordNetLemmatizer()
    porter = PorterStemmer()

    if rule == "lemmatize":
        tokens = [wordnet.lemmatize(word, pos='v') for word in tokens]
    elif rule == "stem":
        tokens = [porter.stem(word) for word in tokens]
    else:
        print("Pick between lemmatize or stem")

    return " ".join(tokens)
# Out:
# <>:29: SyntaxWarning: invalid escape sequence '\s'
# <>:29: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_6047/3213123826.py:29: SyntaxWarning: invalid escape sequence '\s'
#   return re.sub("\s+", " ", text).strip()
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Text Classification using Machine Learning Models

# %% [markdown]
# ### 📝 Instructions: Trump Tweet Sentiment Classification
#
# 1. **Load the Dataset**
#    Load the dataset named `"trump_tweet_sentiment_analysis.csv"` using `pandas`. Ensure the dataset contains at least two columns: `"text"` and `"label"`.
#
# 2. **Text Cleaning and Tokenization**
#    Apply a text preprocessing pipeline to the `"text"` column. This should include:
#    - Lowercasing the text
#    - Removing URLs, mentions, punctuation, and special characters
#    - Removing stopwords
#    - Tokenization (optional: stemming or lemmatization)
#    - "Complete the above function"
#
# 3. **Train-Test Split**
#    Split the cleaned and tokenized dataset into **training** and **testing** sets using `train_test_split` from `sklearn.model_selection`.
#
# 4. **TF-IDF Vectorization**
#    Import and use the `TfidfVectorizer` from `sklearn.feature_extraction.text` to transform the training and testing texts into numerical feature vectors.
#
# 5. **Model Training and Evaluation**
#    Import **Logistic Regression** (or any machine learning model of your choice) from `sklearn.linear_model`. Train it on the TF-IDF-embedded training data, then evaluate it using the test set.
#    - Print the **classification report** using `classification_report` from `sklearn.metrics`.

# %%
print(df.columns)
# Out:
# Index(['text', 'Sentiment', 'clean_text'], dtype='object')

# %%
# Full Text Classification Pipeline

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/trum_tweet_sentiment_analysis.csv")

df["clean_text"] = df["text"].apply(text_cleaning_pipeline)

X_train, X_test, y_train, y_test = train_test_split(
    df["clean_text"], df["Sentiment"], test_size=0.2, random_state=42
)

vectorizer = TfidfVectorizer(max_features=5000)
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

model = LogisticRegression(max_iter=1000)
model.fit(X_train_vec, y_train)

predictions = model.predict(X_test_vec)

print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94    248563
#            1       0.89      0.85      0.87    121462
#
#     accuracy                           0.92    370025
#    macro avg       0.91      0.90      0.91    370025
# weighted avg       0.92      0.92      0.92    370025
